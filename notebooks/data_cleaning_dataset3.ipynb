# %% [markdown]
# # Data Cleaning for `heart_dataset_3.csv`

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
# load dataset
df = pd.read_csv('../data/raw/heart_dataset_3.csv')

display(df.head(), df.info(), df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 60 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   Age                                                                                       368 non-null    int64
#  1   Age.Group                                                                                 368 non-null    object
#  2   Gender                                                                                    368 non-null    object
#  3   Locality                                                                                  368 non-null    object
#  4   Marital status                                                                            368 non-null    object
#  5   Life.Style                                                                                368 non-null    object
#  6   Sleep                                                                                     368 non-null    object
#  7   Category                                                                                  368 non-null    object
#  8   Depression                                                                                368 non-null    object
#  9   Hyperlipi                                                                                 368 non-null    object
#  10  Smoking                                                                                   368 non-null    object
#  11  Family.History                                                                            368 non-null    object
#  12  F.History                                                                                 368 non-null    int64
#  13  Diabetes                                                                                  368 non-null    int64
#  14  HTN                                                                                       368 non-null    object
#  15  Allergies                                                                                 368 non-null    object
#  16  BP                                                                                        368 non-null    float64
#  17  Thrombolysis                                                                              368 non-null    int64
#  18  BGR                                                                                       368 non-null    int64
#  19  B.Urea                                                                                    368 non-null    float64
#  20  S.Cr                                                                                      368 non-null    float64
#  21  S.Sodium                                                                                  368 non-null    int64
#  22  S.Potassium                                                                               368 non-null    float64
#  23  S.Chloride                                                                                368 non-null    int64
#  24  C.P.K                                                                                     368 non-null    int64
#  25  CK.MB                                                                                     368 non-null    int64
#  26  ESR                                                                                       368 non-null    int64
#  27  WBC                                                                                       368 non-null    int64
#  28  RBC                                                                                       368 non-null    float64
#  29  Hemoglobin                                                                                368 non-null    float64
#  30  P.C.V                                                                                     368 non-null    float64
#  31  M.C.V                                                                                     368 non-null    float64
#  32  M.C.H                                                                                     368 non-null    float64
#  33  M.C.H.C                                                                                   368 non-null    float64
#  34  PLATELET_COUNT                                                                            368 non-null    int64
#  35  NEUTROPHIL                                                                                368 non-null    float64
#  36  LYMPHO                                                                                    368 non-null    float64
#  37  MONOCYTE                                                                                  368 non-null    float64
#  38  EOSINO                                                                                    368 non-null    int64
#  39  Others                                                                                    368 non-null    object
#  40  CO                                                                                        368 non-null    object
#  41  Diagnosis                                                                                 368 non-null    object
#  42  Hypersensitivity                                                                          368 non-null    object
#  43  cp                                                                                        368 non-null    int64
#  44  trestbps                                                                                  368 non-null    int64
#  45  chol                                                                                      368 non-null    int64
#  46  fbs                                                                                       368 non-null    int64
#  47  restecg                                                                                   368 non-null    int64
#  48  thalach                                                                                   368 non-null    int64
#  49  exang                                                                                     368 non-null    int64
#  50  oldpeak                                                                                   368 non-null    float64
#  51  slope                                                                                     368 non-null    int64
#  52  ca                                                                                        368 non-null    int64
#  53  thal                                                                                      368 non-null    int64
#  54  num                                                                                       368 non-null    int64
#  55  SK                                                                                        368 non-null    int64
#  56  SK.React                                                                                  368 non-null    object
#  57  Reaction                                                                                  368 non-null    int64
#  58  Mortality                                                                                 368 non-null    int64
#  59  Follow.Up                                                                                 368 non-null    int64
# dtypes: float64(14), int64(28), object(18)
# memory usage: 172.6+ KB
#    Age Age.Group  Gender Locality   Marital status                         \
# 0   45     41-50  Female      RURAL                               MARRIED
# 1   51     51-60  Female      URBAN                               MARRIED
# 2   55     51-60  Female      RURAL                               MARRIED
# 3   55     51-60  Female      RURAL                               MARRIED
# 4   56     51-60  Female      RURAL                               MARRIED
#
#   Life.Style                                                                                \
# 0                                                 NO
# 1                                                 NO
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   Sleep Category Depression Hyperlipi  ... oldpeak slope  ca  thal num SK  \
# 0    NO     FREE        YES       YES  ...     3.0     2   0     7   2  1
# 1    NO     FREE        YES       YES  ...     1.2     2   0     7   2  1
# 2   YES     FREE        YES       YES  ...     3.4     2   0     3   2  1
# 3   YES     FREE        YES       YES  ...     2.0     2   1     7   3  1
# 4    NO     FREE        YES       YES  ...     4.0     3   2     7   3  1
#
#    SK.React  Reaction  Mortality  Follow.Up
# 0        NO         0          0         60
# 1        NO         0          0         15
# 2        NO         0          0          6
# 3        NO         0          0         52
# 4        NO         0          0         34
#
# [5 rows x 60 columns]
# None
# 214

# %%
df = df.drop_duplicates()
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# **We can see that there are no null values and And the duplicated values have been removed.**

# %% [markdown]
# ## Start by renaming columns

# %%
new_column_names = ['age','age_group','sex','locality','marital_status','life_style','sleep','category','depression','hyperlipi','smoking','family_history',\
                            'f_history','diabetes','hypertension','allergies','blood_pressure','thrombolysis','blood_glucose_random','blood_urea','serum_creatinine',\
                            'serum_sodium','serum_potassium','serum_chloride','creatinine_phosphokinase','creatinine_kinase','sedimentation_rate',\
                             'white_blood_cell_count','red_blood_cell_count','hemoglobin','packed_cell_volume','red_cell_volume','red_cell_hemoglobin',\
                            'red_cell_hemoglobin_concentration','platelet_count','neutrophil','lympho','monocyte','eosino','others','CO','diagnosis','hypersensitivity',\
                            'chest_pain_type','resting_bp','cholestorl','fasting_blood_sugar','resting_ecg','max_hr','exercise_angina','oldpeak','st_slope','ca',\
                            'thalassemia','heart_disease_severity','streptokinase_therapy','streptokinase_reaction','reaction','HeartDisease','follow_up']
df.columns = new_column_names
df.head()
# Out:
#    age age_group     sex locality marital_status life_style sleep category  \
# 0   45     41-50  Female    RURAL        MARRIED         NO    NO     FREE
# 1   51     51-60  Female    URBAN        MARRIED         NO    NO     FREE
# 2   55     51-60  Female    RURAL        MARRIED        YES   YES     FREE
# 3   55     51-60  Female    RURAL        MARRIED        YES   YES     FREE
# 4   56     51-60  Female    RURAL        MARRIED        YES    NO     FREE
#
#   depression hyperlipi  ... oldpeak st_slope  ca  thalassemia  \
# 0        YES       YES  ...     3.0        2   0            7
# 1        YES       YES  ...     1.2        2   0            7
# 2        YES       YES  ...     3.4        2   0            3
# 3        YES       YES  ...     2.0        2   1            7
# 4        YES       YES  ...     4.0        3   2            7
#
#   heart_disease_severity streptokinase_therapy  streptokinase_reaction  \
# 0                      2                     1                      NO
# 1                      2                     1                      NO
# 2                      2                     1                      NO
# 3                      3                     1                      NO
# 4                      3                     1                      NO
#
#    reaction  HeartDisease  follow_up
# 0         0             0         60
# 1         0             0         15
# 2         0             0          6
# 3         0             0         52
# 4         0             0         34
#
# [5 rows x 60 columns]

# %% [markdown]
# ## Then by encoding categorial variables

# %%
df.keys()
# Out:
# Index(['age', 'age_group', 'sex', 'locality', 'marital_status', 'life_style',
#        'sleep', 'category', 'depression', 'hyperlipi', 'smoking',
#        'family_history', 'f_history', 'diabetes', 'hypertension', 'allergies',
#        'blood_pressure', 'thrombolysis', 'blood_glucose_random', 'blood_urea',
#        'serum_creatinine', 'serum_sodium', 'serum_potassium', 'serum_chloride',
#        'creatinine_phosphokinase', 'creatinine_kinase', 'sedimentation_rate',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hemoglobin',
#        'packed_cell_volume', 'red_cell_volume', 'red_cell_hemoglobin',
#        'red_cell_hemoglobin_concentration', 'platelet_count', 'neutrophil',
#        'lympho', 'monocyte', 'eosino', 'others', 'CO', 'diagnosis',
#        'hypersensitivity', 'chest_pain_type', 'resting_bp', 'cholestorl',
#        'fasting_blood_sugar', 'resting_ecg', 'max_hr', 'exercise_angina',
#        'oldpeak', 'st_slope', 'ca', 'thalassemia', 'heart_disease_severity',
#        'streptokinase_therapy', 'streptokinase_reaction', 'reaction',
#        'HeartDisease', 'follow_up'],
#       dtype='object')

# %%
# Encode 'sex' column

# turning into binary (1 = M , 0 = F)

df['sex'] = df['sex'].map({'Male': 1, 'Female': 0})
print(df['sex'].unique())
df[['sex']]
# Out:
# [0 1]
#      sex
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ..   ...
# 149    1
# 150    0
# 151    1
# 152    1
# 153    1
#
# [154 rows x 1 columns]

# %%
df = df.drop('age_group',axis='columns')

# %%
df['locality'].unique()
# Out:
# array(['RURAL', 'URBAN'], dtype=object)

# %%
df['locality'] = df['locality'].map({'RURAL': 1, 'URBAN': 0})
print(df['locality'].unique())
df[['locality']]
# Out:
# [1 0]
#      locality
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1
# ..        ...
# 149         1
# 150         1
# 151         0
# 152         0
# 153         1
#
# [154 rows x 1 columns]

# %%
df['marital_status'].unique()
# Out:
# array(['MARRIED', 'SINGLE'], dtype=object)

# %%
df['marital_status'] = df['marital_status'].map({'MARRIED': 1, 'SINGLE': 0})
print(df['marital_status'].unique())
df[['marital_status']]
# Out:
# [1 0]
#      marital_status
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ..              ...
# 149               1
# 150               1
# 151               1
# 152               1
# 153               1
#
# [154 rows x 1 columns]

# %%
df['life_style'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
df = df.drop('life_style',axis='columns')

# %%
df['sleep'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
df['sleep'] = df['sleep'].map({'YES': 1, 'NO': 0})
print(df['sleep'].unique())
df[['sleep']]
# Out:
# [0 1]
#      sleep
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
# ..     ...
# 149      0
# 150      0
# 151      0
# 152      0
# 153      1
#
# [154 rows x 1 columns]

# %%
df['category'].unique()
# Out:
# array(['FREE', 'PAID'], dtype=object)

# %%
df = df.drop('category',axis='columns')

# %%
df['depression'].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
df['depression'] = df['depression'].map({'YES': 1, 'NO': 0})
print(df['depression'].unique())
df[['depression']]
# Out:
# [1 0]
#      depression
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 149           1
# 150           1
# 151           1
# 152           0
# 153           1
#
# [154 rows x 1 columns]

# %%
df['hyperlipi'].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
df['hyperlipi'] = df['hyperlipi'].map({'YES': 1, 'NO': 0})
print(df['hyperlipi'].unique())
df[['hyperlipi']]
# Out:
# [1 0]
#      hyperlipi
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# 149          1
# 150          1
# 151          1
# 152          0
# 153          1
#
# [154 rows x 1 columns]

# %%
df['smoking'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
df['smoking'] = df['smoking'].map({'YES': 1, 'NO': 0})
print(df['smoking'].unique())
df[['smoking']]
# Out:
# [0 1]
#      smoking
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 149        1
# 150        0
# 151        0
# 152        0
# 153        1
#
# [154 rows x 1 columns]

# %%
df['family_history'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
df['family_history'] = df['family_history'].map({'YES': 1, 'NO': 0})
print(df['family_history'].unique())
df[['family_history']]
# Out:
# [0 1]
#      family_history
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 149               0
# 150               0
# 151               0
# 152               0
# 153               0
#
# [154 rows x 1 columns]

# %%
df['hypertension'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
df['hypertension'] = df['hypertension'].map({'YES': 1, 'NO': 0})
print(df['hypertension'].unique())
df[['hypertension']]
# Out:
# [0 1]
#      hypertension
# 0               0
# 1               0
# 2               1
# 3               1
# 4               1
# ..            ...
# 149             1
# 150             1
# 151             1
# 152             0
# 153             0
#
# [154 rows x 1 columns]

# %%
df['allergies'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
df['allergies'] = df['allergies'].map({'YES': 1, 'NO': 0})
print(df['allergies'].unique())
df[['allergies']]
# Out:
# [0 1]
#      allergies
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 149          0
# 150          1
# 151          0
# 152          0
# 153          0
#
# [154 rows x 1 columns]

# %%
df['CO'].unique()
# Out:
# array(['Chest pain,', 'Central Chest pain,',
#        'Chest pain,SOB, Cold sweating', 'CENTRAL Chest pain,',
#        'SOB FROM 1 DAY ', 'Chest pain, SWEATING', 'Chest pain,SOB',
#        'Chest pain 1 hr', 'Chest pain, VOMITING',
#        'Chest pain,heart sinking, vomiting',
#        'Chest pain,nausea,vertigo,sweating,headache', 'Chest pain, 2 HR',
#        'Chest pain,NAUSEA, SWELLOWING',
#        'Chest pain,COLD SWEATING, VOMITING', 'Chest pain,Sweating, ',
#        'Chest pain,vomiting, sweating',
#        'SOB, DIZZINESS, CHEST PAIN,NAUSEA,DIAPHORESIS',
#        'Chest pain, 4 HR', 'Chest pain,SOB, HEART SINKING , PALPITATION',
#        'Chest pain4 HR, SWEATING', 'Chest pain from 3 hr',
#        'Central Chest pain,SOB, Sweating', 'Chest pain,sweating,vomiting',
#        'Chest pain,VOMITING.,SOB', 'Chest pain, Sweating, SOB',
#        'Chest pain,COLD SWEATING, ', 'Chest pain,COUGH',
#        'Chest pain for 2 to 3 hr', 'Chest pain,SWEATING, NAUSEA',
#        'Chest pain, VERTIGO,SWEATING', 'Chest pain, TIGHTNESS',
#        'Chest pain, SOB,', 'Chest pain,VOMITING. SWEATING ',
#        'Chest pain, SWEATING,VOMITING', 'Chest pain, SOB,COLD SWEATING',
#        'Chest pain, COLD SWEATING', 'Chest pain 6 HR'], dtype=object)

# %% [markdown]
# ### Something to note here, 'CO' Column may be too complicated to parse at this moment
#
# ### Revisit Later

# %%
df = df.drop('CO',axis='columns')

# %%
df = df.drop('diagnosis',axis='columns')

# %%
df['hypersensitivity'].unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
df['hypersensitivity'] = df['hypersensitivity'].map({'YES': 1, 'NO': 0})
print(df['hypersensitivity'].unique())
df[['hypersensitivity']]
# Out:
# [0 1]
#      hypersensitivity
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ..                ...
# 149                 1
# 150                 1
# 151                 1
# 152                 0
# 153                 0
#
# [154 rows x 1 columns]

# %%
df = df.drop('streptokinase_reaction',axis='columns')

# %%
df = df.drop('others',axis='columns')

# %%
df = df.drop('follow_up',axis='columns')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154 entries, 0 to 153
# Data columns (total 52 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   age                                154 non-null    int64
#  1   sex                                154 non-null    int64
#  2   locality                           154 non-null    int64
#  3   marital_status                     154 non-null    int64
#  4   sleep                              154 non-null    int64
#  5   depression                         154 non-null    int64
#  6   hyperlipi                          154 non-null    int64
#  7   smoking                            154 non-null    int64
#  8   family_history                     154 non-null    int64
#  9   f_history                          154 non-null    int64
#  10  diabetes                           154 non-null    int64
#  11  hypertension                       154 non-null    int64
#  12  allergies                          154 non-null    int64
#  13  blood_pressure                     154 non-null    float64
#  14  thrombolysis                       154 non-null    int64
#  15  blood_glucose_random               154 non-null    int64
#  16  blood_urea                         154 non-null    float64
#  17  serum_creatinine                   154 non-null    float64
#  18  serum_sodium                       154 non-null    int64
#  19  serum_potassium                    154 non-null    float64
#  20  serum_chloride                     154 non-null    int64
#  21  creatinine_phosphokinase           154 non-null    int64
#  22  creatinine_kinase                  154 non-null    int64
#  23  sedimentation_rate                 154 non-null    int64
#  24  white_blood_cell_count             154 non-null    int64
#  25  red_blood_cell_count               154 non-null    float64
#  26  hemoglobin                         154 non-null    float64
#  27  packed_cell_volume                 154 non-null    float64
#  28  red_cell_volume                    154 non-null    float64
#  29  red_cell_hemoglobin                154 non-null    float64
#  30  red_cell_hemoglobin_concentration  154 non-null    float64
#  31  platelet_count                     154 non-null    int64
#  32  neutrophil                         154 non-null    float64
#  33  lympho                             154 non-null    float64
#  34  monocyte                           154 non-null    float64
#  35  eosino                             154 non-null    int64
#  36  hypersensitivity                   154 non-null    int64
#  37  chest_pain_type                    154 non-null    int64
#  38  resting_bp                         154 non-null    int64
#  39  cholestorl                         154 non-null    int64
#  40  fasting_blood_sugar                154 non-null    int64
#  41  resting_ecg                        154 non-null    int64
#  42  max_hr                             154 non-null    int64
#  43  exercise_angina                    154 non-null    int64
#  44  oldpeak                            154 non-null    float64
#  45  st_slope                           154 non-null    int64
#  46  ca                                 154 non-null    int64
#  47  thalassemia                        154 non-null    int64
#  48  heart_disease_severity             154 non-null    int64
#  49  streptokinase_therapy              154 non-null    int64
#  50  reaction                           154 non-null    int64
#  51  HeartDisease                       154 non-null    int64
# dtypes: float64(14), int64(38)
# memory usage: 63.8 KB

# %%
for i in df.keys():
    print(i, ": ",df[i].unique())
# Out:
# age :  [45 51 55 56 57 58 59 60 61 62 63 65 66 24 25 35 38 40 44 46 47 50 52 53
#  54 64 67 68 69 70 77]
# sex :  [0 1]
# locality :  [1 0]
# marital_status :  [1 0]
# sleep :  [0 1]
# depression :  [1 0]
# hyperlipi :  [1 0]
# smoking :  [0 1]
# family_history :  [0 1]
# f_history :  [0 1]
# diabetes :  [1 0]
# hypertension :  [0 1]
# allergies :  [0 1]
# blood_pressure :  [100.6   90.6  100.7  160.1  140.7  120.8  130.8  160.9  140.9  110.7
#  190.11 160.7  150.9   80.5  120.9  130.9  120.7 ]
# thrombolysis :  [0 1]
# blood_glucose_random :  [ 84 135 146  85 166  96 129 117 164 213 320 152 115 280 210  60 251 363
#  260 125 208 127 323 110 291 426  89 131 348 563 392  86 102 137 153 463
#  231 512]
# blood_urea :  [ 28.   17.   37.   78.  104.   42.   55.   30.   25.   36.   31.   35.
#   40.  394.   33.    2.3  39.   41.   54.   46.   24.   26.   43.   47.
#  162.   61.   38.   27. ]
# serum_creatinine :  [ 0.9   0.7   1.    1.2   4.    1.1  22.9   0.8   0.6   1.08  2.7   1.6
#   1.3 ]
# serum_sodium :  [138 144 137 139 130 146 136 142 135 140 141 134 129 133 145 132 143]
# serum_potassium :  [3.3 4.7 4.2 4.5 5.3 3.9 4.3 4.4 3.8 4.  3.7 4.8 4.6 4.9 4.1]
# serum_chloride :  [107 104 103 112 100 106  98 105 108 110  90  96 109 102]
# creatinine_phosphokinase :  [ 130  163  149   75  322  146   52  203  110  143 2920   61  230  167
#   446 1092  872   66  319   65  583 4289  316  124 3877  159  188   72
#   357  725  387  336 1209  390  684  221  287  174  135   89  693   95
#   111  196]
# creatinine_kinase :  [ 30  22  18  52  21  14  40  20 296  15  32  50  58 113  46  23  51  36
#   45 505  79 299  49  39  85  35  76  75  43  24  16]
# sedimentation_rate :  [ 11  27  19  13 154  25  30  20  14  16  12   5  10   6  24  51  15   9
#   87 104  66  22]
# white_blood_cell_count :  [ 9900 15800  7900  6900 13500  7400  7800  6200 12200  5800 10900 12800
#  17000  9000 17600 12900  9800 14400 15100 11400 10080 12600 14000 14900
#  10300  7600 19590 14800 10400 13800 15000]
# red_blood_cell_count :  [4.26 5.74 4.83 4.41 3.9  4.14 5.12 5.65 5.56 5.28 6.35 5.3  5.4  6.14
#  5.94 6.15 5.46 5.2  5.26 5.7  4.36 4.53 6.98 5.41 5.5  3.46 6.   4.56
#  4.4  4.17 5.   3.7 ]
# hemoglobin :  [11.6 14.5 14.1 12.3 10.  11.7 12.7 15.7 14.8 16.9 18.  15.4 15.5 14.7
#  15.2 16.5 15.6 15.3 11.5 13.3 13.9 16.3 11.2 13.6 16.6 10.3 10.1 15.
#   9.1 13.7 14.3 10.8]
# packed_cell_volume :  [0.34 0.44 0.42 0.36 0.29 0.4  0.47 0.43 0.5  0.46 0.45 0.51 0.41 0.48
#  0.33 0.35 0.52 0.54 0.32]
# red_cell_volume :  [79.7 78.  87.  82.  74.4 83.7 84.  79.  83.6 86.5 83.  74.  82.1 86.8
#  86.  81.  72.  77.  76.6 78.1 60.  85.  77.7 91.1 65.  96.  93.9]
# red_cell_hemoglobin :  [27.2 25.  29.  27.  25.7 28.  27.8 26.  28.9 33.  30.2 24.  26.9 28.6
#  23.  30.1 18.  29.3 24.6 30.8 20.  32.4]
# red_cell_hemoglobin_concentration :  [0.34 0.32 0.33 0.35 0.31 0.38 0.39 0.22]
# platelet_count :  [265000 287000 183000 211000 288000 395000 187000 281000 192000 186000
#  244000 459000 235000 178000 237000 306000 236000 277000 290000 153000
#  239000 391000 214000 217000 136000 268000 238000 261000 171000 284000
#  347000 297000 222000  20000 433000 228000]
# neutrophil :  [ 0.7   0.73  0.6   0.71  0.85  0.63  0.66  0.81  0.5   0.36  0.65  0.44
#   0.8  83.    0.75  0.55  0.47  0.9   0.74  0.57  0.78  0.69  0.79  0.76
#   0.91  0.82  0.72]
# lympho :  [0.25 0.2  0.33 0.1  0.31 0.28 0.35 0.15 0.43 0.54 0.26 0.49 0.14 0.17
#  0.42 0.45 0.4  0.08 0.32 0.18 0.05 0.07 0.21 0.22]
# monocyte :  [0.03 0.04 0.02 0.06 0.08 0.01 0.05 0.07]
# eosino :  [2 3 4 1 5]
# hypersensitivity :  [0 1]
# chest_pain_type :  [4 2 3 1]
# resting_bp :  [132 130 180 128 200 134 140 136 170 174 150 158 145 160 138 108 124 178
#  120 126 118 110 152 112 142 144 125 123 192 122 165 154 100 146 114 164
#  117 148 135]
# cholestorl :  [341 305 327 205 288 409 241 236 319 225 249 258 330 307 268 164 263 294
#  244 407 269 197 228 198 282 231 219 167 223 172 315 177 247 290 169 309
#  264 311 243 275 229 256 274 188 149 233 200 299 298 255 230 212 204 203
#  266 239 283 206 286 353 217 289 184 276 261 232 335 131 284 224 216 270
#  300 259 234 218 318 326 273 176 253 185 293 260 166 207 267 281 254 187
#  246 248 237 193 174 322 304]
# fasting_blood_sugar :  [1 0]
# resting_ecg :  [2 0 1]
# max_hr :  [136 142 117 130 133 150 123 174 152 146 143 157 161 169 160 145  97 106
#  154 114 165 156 182 140 181 158 125 120 153 177 144 147 132 118 168 166
#  139 126 128 163 173 122 155  95 109 113 195 108 116 111 105 103 112 124
#   88 141 164 115 131 171 162 159 134  90 170 138  99  96 127 129  71]
# exercise_angina :  [1 0]
# oldpeak :  [3.  1.2 3.4 2.  4.  1.9 0.2 0.  2.8 2.6 1.  3.6 6.2 1.4 1.8 1.6 3.8 2.5
#  0.1 0.8 0.5 0.6 0.9 4.2 3.1 2.2 3.2 5.6 2.1 0.4 0.3 4.4 2.4 1.5 2.9]
# st_slope :  [2 3 1]
# ca :  [0 1 2 3]
# thalassemia :  [7 3 6]
# heart_disease_severity :  [2 3 1 4]
# streptokinase_therapy :  [1 0]
# reaction :  [0 1]
# HeartDisease :  [0 1]

# %% [markdown]
# ## Now standardize features
# ### Age, RestingBP, Cholesterol, MaxHR, oldpeak, etc

# %%
scaler = StandardScaler()

columns_so_scale = ['age', 'blood_pressure', 'blood_glucose_random', 'blood_urea', 'serum_creatinine','serum_sodium','serum_potassium',\
                    'serum_chloride','creatinine_phosphokinase','creatinine_kinase','sedimentation_rate','white_blood_cell_count',\
                   'red_blood_cell_count','hemoglobin','packed_cell_volume','red_cell_volume','red_cell_hemoglobin',\
                   'red_cell_hemoglobin_concentration','platelet_count','neutrophil','lympho','monocyte','eosino','resting_bp',\
                   'cholestorl','max_hr','oldpeak']
df[columns_so_scale] = scaler.fit_transform(df[columns_so_scale])

# %%
df.head()
# Out:
#         age  sex  locality  marital_status  sleep  depression  hyperlipi  \
# 0 -1.195961    0         1               1      0           1          1
# 1 -0.529856    0         0               1      0           1          1
# 2 -0.085786    0         1               1      1           1          1
# 3 -0.085786    0         1               1      1           1          1
# 4  0.025231    0         1               1      0           1          1
#
#    smoking  family_history  f_history  ...    max_hr  exercise_angina  \
# 0        0               0          0  ... -0.177879                1
# 1        0               0          0  ...  0.089373                1
# 2        0               0          0  ... -1.024179                1
# 3        0               0          0  ... -0.445132                1
# 4        0               0          0  ... -0.311506                1
#
#     oldpeak  st_slope  ca  thalassemia  heart_disease_severity  \
# 0  1.133205         2   0            7                       2
# 1 -0.255497         2   0            7                       2
# 2  1.441806         2   0            3                       2
# 3  0.361704         2   1            7                       3
# 4  1.904706         3   2            7                       3
#
#    streptokinase_therapy  reaction  HeartDisease
# 0                      1         0             0
# 1                      1         0             0
# 2                      1         0             0
# 3                      1         0             0
# 4                      1         0             0
#
# [5 rows x 52 columns]

# %%
for i in df.keys():
    print(i, ": ",df[i].unique())
# Out:
# age :  [-1.19596124 -0.52985625 -0.08578625  0.02523125  0.13624875  0.24726625
#   0.35828375  0.46930125  0.58031875  0.69133625  0.80235374  1.02438874
#   1.13540624 -3.52732873 -3.41631123 -2.30613623 -1.97308374 -1.75104874
#  -1.30697874 -1.08494374 -0.97392624 -0.64087375 -0.41883875 -0.30782125
#  -0.19680375  0.91337124  1.24642374  1.35744124  1.46845874  1.57947624
#   2.35659873]
# sex :  [0 1]
# locality :  [1 0]
# marital_status :  [1 0]
# sleep :  [0 1]
# depression :  [1 0]
# hyperlipi :  [1 0]
# smoking :  [0 1]
# family_history :  [0 1]
# f_history :  [0 1]
# diabetes :  [1 0]
# hypertension :  [0 1]
# allergies :  [0 1]
# blood_pressure :  [-0.75122061 -1.17888203 -0.746944    1.79336485  0.96370169  0.11265546
